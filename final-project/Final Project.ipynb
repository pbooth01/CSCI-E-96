# %% [markdown]
# # CSCI S-96 Final Project
# ## Real Estate Clustering Models
# ## Phillip Booth

# %% [markdown]
# ## Introduction
#
# **Clustering models** are core data mining methods. Clustering models are also known as **unsupervised learning** models. The goal of these models is to extract structure and relationships from complex data. Carrying out this type of exploration is difficult since there is no ground truth as a basis of comparison.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

from sklearn.decomposition import PCA, KernelPCA
from sklearn.cluster import KMeans, AgglomerativeClustering, SpectralClustering, OPTICS, MiniBatchKMeans
from sklearn.metrics import silhouette_score
from sklearn.manifold import SpectralEmbedding, MDS
from sklearn.metrics.pairwise import pairwise_distances 
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

import itertools
import time
from pathlib import Path

# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Constants

# %%
# Currently my housing search is limited to Massachusetts and New Hampshire
STATES_CONSIDERED = ['MA', 'NH']
ZIP_CODE_PREFIXES = {
    'MA': 0,
    'NH': 0
}

ATOM_API_KEY = "d8188fda10d5747de082ca4cde8adcc7"
ATOM_API_SLEEP_LENGTH = 1
ATOM_COMMUNITY_API_ENDPOINT = "https://api.gateway.attomdata.com/communityapi/v2.0.0/area/full"
# Change this if you want to save a new file with anew name
ATOM_OUTPUT_FILE_TAG = "NH"

# %% [markdown]
# ### Getting the associated US Zip Codes

# %%
zip_code_df = pd.read_excel('data/zip_code_database.xls')
print("zip code df shape: ", zip_code_df.shape)
zip_code_df.head()
# Out:
# zip code df shape:  (42632, 15)
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                               I R S Service Center    NY
# 1                                 Irs Service Center    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone  area_codes world_region country  \
# 0       Suffolk County     America/New_York       631.0          NaN      US
# 1       Suffolk County     America/New_York       631.0          NaN      US
# 2   Adjuntas Municipio  America/Puerto_Rico    787939.0          NaN      US
# 3     Aguada Municipio  America/Puerto_Rico    787939.0          NaN      US
# 4  Aguadilla Municipio  America/Puerto_Rico       787.0          NaN      US
#
#    latitude  longitude  irs_estimated_population_2015
# 0     40.81     -73.04                            562
# 1     40.81     -73.04                              0
# 2     18.16     -66.72                              0
# 3     18.38     -67.18                              0
# 4     18.43     -67.15                              0

# %%
# Filter the zip codes down into the ones that I care about for my housing search

zip_code_filtered_df = zip_code_df[zip_code_df['state'].isin(STATES_CONSIDERED)]
print("filtered zip code df shape: ", zip_code_filtered_df.shape)
# Out:
# filtered zip code df shape:  (284, 15)

# %%
zip_code_filtered_df[zip_code_filtered_df['primary_city'] == "Andover"]
# Out:
#        zip      type  decommissioned primary_city acceptable_cities  \
# 1036  3216  STANDARD               0      Andover               NaN
#
#      unacceptable_cities state            county          timezone  \
# 1036                 NaN    NH  Merrimack County  America/New_York
#
#       area_codes world_region country  latitude  longitude  \
# 1036       603.0          NaN      US     43.43     -71.82
#
#       irs_estimated_population_2015
# 1036                           1940

# %% [markdown]
# Based on this post: https://www.policymap.com/2013/04/tips-on-zips-part-iii-making-sense-of-zip-code-boundaries/
#
# It seems like there are many different types of zip codes. We are only interested in the Standard Ones.

# %%
zip_code_filtered_df = zip_code_filtered_df[zip_code_filtered_df['type'] == "STANDARD"]
print("filtered zip code df shape: ", zip_code_filtered_df.shape)
# Out:
# filtered zip code df shape:  (233, 15)

# %% [markdown]
# ## Getting Accessible Data from Atom Data Solutions By Zip Code
#
# Now that I have the list of zip codes it is time to use the Atom Real estate API to get data for each zip code that I am interested in so I can put together a picture of each zip code.

# %%
GLOBAL_PROCESSED_ZIPCODES = []

def get_processed_zips_from_atom_df():
    atom_file_path = 'data/atom_output_{0}.csv'.format(ATOM_OUTPUT_FILE_TAG)
    
    atom_output_file = Path(atom_file_path)
    
    if atom_output_file.exists():
        atom_df = pd.read_csv(atom_output_file)
        return atom_df['geo_code'].unique()
    else:
        return []

def getAtomData(zip_df):
    
    GLOBAL_PROCESSED_ZIPCODES = get_processed_zips_from_atom_df()
    
    missed_zip_codes = []
    current_output_to_write = []
    cur_processing_number = 0
    num_disk_writes = 0
    
    headers = {'Accept': 'application/json', 'APIKey': ATOM_API_KEY}
    
    for index, row in zip_df.iterrows():
        if row['state'] in ZIP_CODE_PREFIXES:
            
            cur_processing_number += 1
            # The zip code data set does not include the first number of the zipcode
            zip_prefix = ZIP_CODE_PREFIXES[row['state']]

            full_zip_str = str(zip_prefix) + str(row['zip'])
            
            if row['zip'] not in GLOBAL_PROCESSED_ZIPCODES:

                ## Build URL For Request
                atom_url = ATOM_COMMUNITY_API_ENDPOINT + "?AreaId=ZI" + full_zip_str

                atom_resp = requests.get(atom_url, headers=headers)

                if atom_resp.status_code != 200:
                    # We will need to check and see what happened here 
                    missed_zip_codes.append(full_zip_str)
                    print("ATOM Request failed for url: ", atom_url)
                    continue

                atom_resp_json = atom_resp.json()
                
                current_output_to_write.append(atom_resp_json['response']['result']['package']['item'][0])

                if len(current_output_to_write) == 20:
                    process_atom_data_and_save_to_disk(current_output_to_write, num_disk_writes)
                    num_disk_writes += 1
                    
                    # After saving to disk we need to update our PROCESSED ZIP information
                    processed_zips = list(map(lambda x: x["geo_code"], current_output_to_write))
                    GLOBAL_PROCESSED_ZIPCODES = np.append(GLOBAL_PROCESSED_ZIPCODES, processed_zips)
                        
                    current_output_to_write = []
                    print("current number of missed zips is: ", len(missed_zip_codes))
                    print("*******Processed {0} total zipcodes *****".format(cur_processing_number))
                
                # need to sleep for 6 seconds between calls to avoid 10 per min api limits
                time.sleep(6)
            else:
                print("SKIPPING Already Processed Zip Code: ", full_zip_str)
        else:
            raise Exception("STATE DOES NOT EXIST IN ZIP_CODE_PREFIXES CONSTANT")

    # Save whatever is left to disk      
    process_atom_data_and_save_to_disk(current_output_to_write, num_disk_writes)

    processed_zips = list(map(lambda x: x["geo_code"], current_output_to_write))
    GLOBAL_PROCESSED_ZIPCODES = np.append(GLOBAL_PROCESSED_ZIPCODES, processed_zips)
    
    print("Finished Retreiving Atom Data")
    print("{0} Zip Codes Were Missed".format(len(missed_zip_codes)))
            
def process_atom_data_and_save_to_disk(new_values, write_number):
    atom_file_path = 'data/atom_output_{0}.csv'.format(ATOM_OUTPUT_FILE_TAG)
    print("Processing File: {0} for disk write number: {1}".format(atom_file_path, write_number))
    
    atom_output_file = Path(atom_file_path)
    
    if atom_output_file.exists():
        atom_df = pd.read_csv(atom_output_file)
        atom_df = atom_df.append(pd.DataFrame(new_values), ignore_index=True)
    else:
        atom_df = pd.DataFrame(new_values)
    
    atom_df.to_csv(atom_output_file, index=False)  
    
    print("Finished Disk Write")

# %%
getAtomData(zip_code_filtered_df[['zip', 'state']])
# Out:
# SKIPPING Already Processed Zip Code:  03031
# SKIPPING Already Processed Zip Code:  03032
# SKIPPING Already Processed Zip Code:  03033
# SKIPPING Already Processed Zip Code:  03034
# SKIPPING Already Processed Zip Code:  03036
# SKIPPING Already Processed Zip Code:  03037
# SKIPPING Already Processed Zip Code:  03038
# SKIPPING Already Processed Zip Code:  03042
# SKIPPING Already Processed Zip Code:  03043
# SKIPPING Already Processed Zip Code:  03044
# SKIPPING Already Processed Zip Code:  03045
# SKIPPING Already Processed Zip Code:  03046
# SKIPPING Already Processed Zip Code:  03047
# SKIPPING Already Processed Zip Code:  03048
# SKIPPING Already Processed Zip Code:  03049
# SKIPPING Already Processed Zip Code:  03051
# SKIPPING Already Processed Zip Code:  03052
# SKIPPING Already Processed Zip Code:  03053
# SKIPPING Already Processed Zip Code:  03054
# SKIPPING Already Processed Zip Code:  03055
# SKIPPING Already Processed Zip Code:  03057
# SKIPPING Already Processed Zip Code:  03060
# SKIPPING Already Processed Zip Code:  03062
# SKIPPING Already Processed Zip Code:  03063
# SKIPPING Already Processed Zip Code:  03064
# SKIPPING Already Processed Zip Code:  03070
# SKIPPING Already Processed Zip Code:  03071
# SKIPPING Already Processed Zip Code:  03076
# SKIPPING Already Processed Zip Code:  03077
# SKIPPING Already Processed Zip Code:  03079
# SKIPPING Already Processed Zip Code:  03082
# SKIPPING Already Processed Zip Code:  03084
# SKIPPING Already Processed Zip Code:  03086
# SKIPPING Already Processed Zip Code:  03087
# SKIPPING Already Processed Zip Code:  03101
# SKIPPING Already Processed Zip Code:  03102
# SKIPPING Already Processed Zip Code:  03103
# SKIPPING Already Processed Zip Code:  03104
# SKIPPING Already Processed Zip Code:  03106
# SKIPPING Already Processed Zip Code:  03109
# SKIPPING Already Processed Zip Code:  03110
# SKIPPING Already Processed Zip Code:  03216
# SKIPPING Already Processed Zip Code:  03217
# SKIPPING Already Processed Zip Code:  03218
# SKIPPING Already Processed Zip Code:  03220
# SKIPPING Already Processed Zip Code:  03221
# SKIPPING Already Processed Zip Code:  03222
# SKIPPING Already Processed Zip Code:  03223
# SKIPPING Already Processed Zip Code:  03224
# SKIPPING Already Processed Zip Code:  03225
# SKIPPING Already Processed Zip Code:  03226
# SKIPPING Already Processed Zip Code:  03227
# SKIPPING Already Processed Zip Code:  03229
# SKIPPING Already Processed Zip Code:  03230
# SKIPPING Already Processed Zip Code:  03233
# SKIPPING Already Processed Zip Code:  03234
# SKIPPING Already Processed Zip Code:  03235
# SKIPPING Already Processed Zip Code:  03237
# SKIPPING Already Processed Zip Code:  03240
# SKIPPING Already Processed Zip Code:  03241
# SKIPPING Already Processed Zip Code:  03242
# SKIPPING Already Processed Zip Code:  03243
# SKIPPING Already Processed Zip Code:  03244
# SKIPPING Already Processed Zip Code:  03245
# SKIPPING Already Processed Zip Code:  03246
# SKIPPING Already Processed Zip Code:  03249
# SKIPPING Already Processed Zip Code:  03251
# SKIPPING Already Processed Zip Code:  03253
# SKIPPING Already Processed Zip Code:  03254
# SKIPPING Already Processed Zip Code:  03255
# SKIPPING Already Processed Zip Code:  03256
# SKIPPING Already Processed Zip Code:  03257
# SKIPPING Already Processed Zip Code:  03258
# SKIPPING Already Processed Zip Code:  03259
# SKIPPING Already Processed Zip Code:  03261
# SKIPPING Already Processed Zip Code:  03262
# SKIPPING Already Processed Zip Code:  03263
# SKIPPING Already Processed Zip Code:  03264
# SKIPPING Already Processed Zip Code:  03266
# SKIPPING Already Processed Zip Code:  03268
# SKIPPING Already Processed Zip Code:  03269
# SKIPPING Already Processed Zip Code:  03275
# SKIPPING Already Processed Zip Code:  03276
# SKIPPING Already Processed Zip Code:  03278
# SKIPPING Already Processed Zip Code:  03279
# SKIPPING Already Processed Zip Code:  03280
# SKIPPING Already Processed Zip Code:  03281
# SKIPPING Already Processed Zip Code:  03282
# SKIPPING Already Processed Zip Code:  03284
# SKIPPING Already Processed Zip Code:  03285
# SKIPPING Already Processed Zip Code:  03287
# SKIPPING Already Processed Zip Code:  03290
# SKIPPING Already Processed Zip Code:  03291
# SKIPPING Already Processed Zip Code:  03301
# SKIPPING Already Processed Zip Code:  03303
# SKIPPING Already Processed Zip Code:  03304
# SKIPPING Already Processed Zip Code:  03307
# SKIPPING Already Processed Zip Code:  03431
# SKIPPING Already Processed Zip Code:  03440
# SKIPPING Already Processed Zip Code:  03441
# SKIPPING Already Processed Zip Code:  03442
# SKIPPING Already Processed Zip Code:  03443
# SKIPPING Already Processed Zip Code:  03444
# SKIPPING Already Processed Zip Code:  03445
# SKIPPING Already Processed Zip Code:  03446
# SKIPPING Already Processed Zip Code:  03447
# SKIPPING Already Processed Zip Code:  03448
# SKIPPING Already Processed Zip Code:  03449
# SKIPPING Already Processed Zip Code:  03450
# SKIPPING Already Processed Zip Code:  03451
# SKIPPING Already Processed Zip Code:  03452
# SKIPPING Already Processed Zip Code:  03455
# SKIPPING Already Processed Zip Code:  03456
# SKIPPING Already Processed Zip Code:  03457
# SKIPPING Already Processed Zip Code:  03458
# SKIPPING Already Processed Zip Code:  03461
# SKIPPING Already Processed Zip Code:  03462
# SKIPPING Already Processed Zip Code:  03464
# SKIPPING Already Processed Zip Code:  03465
# SKIPPING Already Processed Zip Code:  03466
# SKIPPING Already Processed Zip Code:  03467
# SKIPPING Already Processed Zip Code:  03470
# SKIPPING Already Processed Zip Code:  03561
# SKIPPING Already Processed Zip Code:  03570
# SKIPPING Already Processed Zip Code:  03574
# SKIPPING Already Processed Zip Code:  03576
# SKIPPING Already Processed Zip Code:  03579
# SKIPPING Already Processed Zip Code:  03580
# SKIPPING Already Processed Zip Code:  03581
# SKIPPING Already Processed Zip Code:  03582
# SKIPPING Already Processed Zip Code:  03583
# SKIPPING Already Processed Zip Code:  03584
# SKIPPING Already Processed Zip Code:  03585
# SKIPPING Already Processed Zip Code:  03586
# SKIPPING Already Processed Zip Code:  03588
# SKIPPING Already Processed Zip Code:  03590
# SKIPPING Already Processed Zip Code:  03592
# SKIPPING Already Processed Zip Code:  03593
# SKIPPING Already Processed Zip Code:  03598
# SKIPPING Already Processed Zip Code:  03601
# SKIPPING Already Processed Zip Code:  03602
# SKIPPING Already Processed Zip Code:  03603
# SKIPPING Already Processed Zip Code:  03605
# SKIPPING Already Processed Zip Code:  03607
# SKIPPING Already Processed Zip Code:  03608
# SKIPPING Already Processed Zip Code:  03609
# SKIPPING Already Processed Zip Code:  03740
# SKIPPING Already Processed Zip Code:  03741
# SKIPPING Already Processed Zip Code:  03743
# SKIPPING Already Processed Zip Code:  03745
# SKIPPING Already Processed Zip Code:  03748
# SKIPPING Already Processed Zip Code:  03750
# SKIPPING Already Processed Zip Code:  03752
# SKIPPING Already Processed Zip Code:  03753
# SKIPPING Already Processed Zip Code:  03755
# SKIPPING Already Processed Zip Code:  03765
# SKIPPING Already Processed Zip Code:  03766
# SKIPPING Already Processed Zip Code:  03768
# SKIPPING Already Processed Zip Code:  03770
# SKIPPING Already Processed Zip Code:  03771
# SKIPPING Already Processed Zip Code:  03773
# SKIPPING Already Processed Zip Code:  03774
# SKIPPING Already Processed Zip Code:  03777
# SKIPPING Already Processed Zip Code:  03779
# SKIPPING Already Processed Zip Code:  03780
# SKIPPING Already Processed Zip Code:  03781
# SKIPPING Already Processed Zip Code:  03782
# SKIPPING Already Processed Zip Code:  03784
# SKIPPING Already Processed Zip Code:  03785
# SKIPPING Already Processed Zip Code:  03801
# ATOM Request failed for url:  https://api.gateway.attomdata.com/communityapi/v2.0.0/area/full?AreaId=ZI03805
# SKIPPING Already Processed Zip Code:  03809
# SKIPPING Already Processed Zip Code:  03810
# SKIPPING Already Processed Zip Code:  03811
# SKIPPING Already Processed Zip Code:  03812
# SKIPPING Already Processed Zip Code:  03813
# SKIPPING Already Processed Zip Code:  03814
# ATOM Request failed for url:  https://api.gateway.attomdata.com/communityapi/v2.0.0/area/full?AreaId=ZI03815
# SKIPPING Already Processed Zip Code:  03816
# SKIPPING Already Processed Zip Code:  03817
# SKIPPING Already Processed Zip Code:  03818
# SKIPPING Already Processed Zip Code:  03819
# SKIPPING Already Processed Zip Code:  03820
# SKIPPING Already Processed Zip Code:  03823
# SKIPPING Already Processed Zip Code:  03824
# SKIPPING Already Processed Zip Code:  03825
# SKIPPING Already Processed Zip Code:  03826
# SKIPPING Already Processed Zip Code:  03827
# SKIPPING Already Processed Zip Code:  03830
# SKIPPING Already Processed Zip Code:  03833
# SKIPPING Already Processed Zip Code:  03835
# SKIPPING Already Processed Zip Code:  03836
# SKIPPING Already Processed Zip Code:  03837
# SKIPPING Already Processed Zip Code:  03838
# SKIPPING Already Processed Zip Code:  03839
# SKIPPING Already Processed Zip Code:  03840
# SKIPPING Already Processed Zip Code:  03841
# SKIPPING Already Processed Zip Code:  03842
# SKIPPING Already Processed Zip Code:  03844
# SKIPPING Already Processed Zip Code:  03845
# SKIPPING Already Processed Zip Code:  03846
# SKIPPING Already Processed Zip Code:  03848
# SKIPPING Already Processed Zip Code:  03849
# SKIPPING Already Processed Zip Code:  03851
# SKIPPING Already Processed Zip Code:  03852
# SKIPPING Already Processed Zip Code:  03853
# SKIPPING Already Processed Zip Code:  03855
# SKIPPING Already Processed Zip Code:  03856
# SKIPPING Already Processed Zip Code:  03857
# SKIPPING Already Processed Zip Code:  03858
# SKIPPING Already Processed Zip Code:  03860
# SKIPPING Already Processed Zip Code:  03861
# SKIPPING Already Processed Zip Code:  03862
# SKIPPING Already Processed Zip Code:  03864
# SKIPPING Already Processed Zip Code:  03865
# SKIPPING Already Processed Zip Code:  03867
# SKIPPING Already Processed Zip Code:  03868
# ATOM Request failed for url:  https://api.gateway.attomdata.com/communityapi/v2.0.0/area/full?AreaId=ZI03897
# Processing File: data/atom_output_NH.csv for disk write number: 0
# Finished Disk Write
# Finished Retreiving Atom Data
# 3 Zip Codes Were Missed
